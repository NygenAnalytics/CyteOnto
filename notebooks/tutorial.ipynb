# %% [markdown]
# # CyteOnto Tutorial
#
# This is a basic tutorial on how to use `cyteonto` package for comparing cluster labels.
#
# **Note**: Make sure you have downloaded the precomputed embeddings and descriptions if you plan to use `Kimi-K2` as text and `Qwen3-8B` as embedding model.
#
# ```bash
# EMBEDDING_MODEL_API_KEY=deepinfra_api_key   # We are using deepinfra as model provider
# DEEPINFRA_API_KEY=deepinfra_api_key
# ```

# %%
import sys
sys.path.append("..")

# %%
import os

from pydantic_ai import Agent
from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider

import cyteonto

# %%
model = OpenAIModel(
    "moonshotai/Kimi-K2-Instruct",
    provider=OpenAIProvider(
        base_url="https://api.deepinfra.com/v1/openai",
        api_key=os.getenv("DEEPINFRA_API_KEY"),
    ),
)
agent = Agent(model)

# %%
# one time setup
await cyteonto.setup(
    base_agent=agent,
    embedding_model="Qwen/Qwen3-Embedding-8B",
    embedding_provider="deepinfra",
)

# %%
author_labels = [
    "animal stem cell",
    "BFU-E",
    "CFU-M",
    "neutrophilic granuloblast"
]
labels1 = [
    "stem cell",
    "blast forming unit erythroid",
    "erythroid stem cell",
    "spermatogonium"
]
labels2 = [
    "neuronal receptor cell",
    "stem cell",
    "smooth muscle cell neural crest derived",
    "ovum"
]

# %%
# Initialize CyteOnto instance
cyto = cyteonto.CyteOnto(
    base_agent=agent,
    embedding_model="Qwen/Qwen3-Embedding-8B", 
    embedding_provider="deepinfra"
)

# %%
# Compare multiple algorithms at once - no file collision!
algo_comparison_data = [
    ("CyteType", labels1),
    ("CellTypist", labels2)
    # keep here 
]

results_df = await cyto.compare_batch(
    author_labels=author_labels,
    algo_comparison_data=algo_comparison_data,
    study_name="sample_study"
)

# %%
results_df
# Out:
#      study_name   algorithm  pair_index               author_label  \
# 0  sample_study    CyteType           0           animal stem cell
# 1  sample_study    CyteType           1                      BFU-E
# 2  sample_study    CyteType           2                      CFU-M
# 3  sample_study    CyteType           3  neutrophilic granuloblast
# 4  sample_study  CellTypist           0           animal stem cell
# 5  sample_study  CellTypist           1                      BFU-E
# 6  sample_study  CellTypist           2                      CFU-M
# 7  sample_study  CellTypist           3  neutrophilic granuloblast
#
#                            algorithm_label author_ontology_id  \
# 0                                stem cell         CL:0000034
# 1             blast forming unit erythroid         CL:0001066
# 2                      erythroid stem cell         CL:0000049
# 3                           spermatogonium         CL:0000042
# 4                   neuronal receptor cell         CL:0000034
# 5                                stem cell         CL:0001066
# 6  smooth muscle cell neural crest derived         CL:0000049
# 7                                     ovum         CL:0000042
#
#    author_embedding_similarity algorithm_ontology_id  \
# 0                       0.9169            CL:0000723
# 1                       0.8798            CL:0001066
# 2                       0.7403            CL:0001066
# 3                       0.9121            CL:0000020
# 4                       0.9169            CL:0000197
# 5                       0.8798            CL:0001024
# 6                       0.7403            CL:0000027
# 7                       0.9121            CL:0000025
#
#    algorithm_embedding_similarity  ontology_hierarchy_similarity  \
# 0                          0.8014                         0.9868
# 1                          0.8379                         1.0000
# 2                          0.8645                         0.9065
# 3                          0.9150                         0.7566
# 4                          0.8493                         0.9499
# 5                          0.8577                         0.9174
# 6                          0.9157                         0.8703
# 7                          0.9137                         0.8222
#
#     similarity_method
# 0  ontology_hierarchy
# 1  ontology_hierarchy
# 2  ontology_hierarchy
# 3  ontology_hierarchy
# 4  ontology_hierarchy
# 5  ontology_hierarchy
# 6  ontology_hierarchy
# 7  ontology_hierarchy

# %%
# Check overall performance by similarity method
print(results_df['similarity_method'].value_counts())
# Out:
# similarity_method
# ontology_hierarchy    8
# Name: count, dtype: int64

# %%
# Get high-quality matches (both labels matched well)
high_quality = results_df[
    (results_df['author_embedding_similarity'] > 0.7) 
    & 
    (results_df['algorithm_embedding_similarity'] > 0.7) 
    &
    (results_df['similarity_method'] == 'ontology_hierarchy')
]
high_quality
# Out:
#      study_name   algorithm  pair_index               author_label  \
# 0  sample_study    CyteType           0           animal stem cell
# 1  sample_study    CyteType           1                      BFU-E
# 2  sample_study    CyteType           2                      CFU-M
# 3  sample_study    CyteType           3  neutrophilic granuloblast
# 4  sample_study  CellTypist           0           animal stem cell
# 5  sample_study  CellTypist           1                      BFU-E
# 6  sample_study  CellTypist           2                      CFU-M
# 7  sample_study  CellTypist           3  neutrophilic granuloblast
#
#                            algorithm_label author_ontology_id  \
# 0                                stem cell         CL:0000034
# 1             blast forming unit erythroid         CL:0001066
# 2                      erythroid stem cell         CL:0000049
# 3                           spermatogonium         CL:0000042
# 4                   neuronal receptor cell         CL:0000034
# 5                                stem cell         CL:0001066
# 6  smooth muscle cell neural crest derived         CL:0000049
# 7                                     ovum         CL:0000042
#
#    author_embedding_similarity algorithm_ontology_id  \
# 0                       0.9169            CL:0000723
# 1                       0.8798            CL:0001066
# 2                       0.7403            CL:0001066
# 3                       0.9121            CL:0000020
# 4                       0.9169            CL:0000197
# 5                       0.8798            CL:0001024
# 6                       0.7403            CL:0000027
# 7                       0.9121            CL:0000025
#
#    algorithm_embedding_similarity  ontology_hierarchy_similarity  \
# 0                          0.8014                         0.9868
# 1                          0.8379                         1.0000
# 2                          0.8645                         0.9065
# 3                          0.9150                         0.7566
# 4                          0.8493                         0.9499
# 5                          0.8577                         0.9174
# 6                          0.9157                         0.8703
# 7                          0.9137                         0.8222
#
#     similarity_method
# 0  ontology_hierarchy
# 1  ontology_hierarchy
# 2  ontology_hierarchy
# 3  ontology_hierarchy
# 4  ontology_hierarchy
# 5  ontology_hierarchy
# 6  ontology_hierarchy
# 7  ontology_hierarchy

# %%
# Compare algorithms
for algo in results_df['algorithm'].unique():
    algo_data = results_df[results_df['algorithm'] == algo]
    median_sim = algo_data['ontology_hierarchy_similarity'].median()
    print(f"{algo}: {median_sim:.3f} median ontology similarity")
# Out:
# CyteType: 0.947 median ontology similarity
# CellTypist: 0.894 median ontology similarity

# %%
# Find problematic matches
low_embedding_matches = results_df[
    (results_df['author_embedding_similarity'] < 0.5) |
    (results_df['algorithm_embedding_similarity'] < 0.5)
]
print("Labels with poor ontology matching:")
print(low_embedding_matches[['author_label', 'algorithm_label', 'similarity_method']])
# Out:
# Labels with poor ontology matching:
# Empty DataFrame
# Columns: [author_label, algorithm_label, similarity_method]
# Index: []
